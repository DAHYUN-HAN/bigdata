# %% [markdown]
# 시리즈는 모든 데이터 유형을 저장 할 수 있는 1차원 레이블이 지정된 배열이다.

# %%
import pandas as pd
sd1 = pd.Series(['Dog','Cat','Tiger','Lion','Monkey'], index=['0','1','2','3','4'])

sd1
# Out:
# 0       Dog
# 1       Cat
# 2     Tiger
# 3      Lion
# 4    Monkey
# dtype: object

# %% [markdown]
# 딕셔너리는 트리 형식의 검색 자료구조로 {Key : Value}로 값을 저장한다.

# %%
import pandas as pd

dict_data = {'a':1, 'b':2, 'c':3}
sd2 = pd.Series(dict_data)

type(sd2)
sd2
# Out:
# a    1
# b    2
# c    3
# dtype: int64

# %% [markdown]
# 리스트는 key 값이 없는 순서 자료형이고, 인덱스는 자동으로 0부터 지정된다.

# %%
import pandas as pd

list_data = pd.Series(['Dog','Cat','Tiger','Lion','Monkey'])
sd3 = pd.Series(list_data)
sd3
# Out:
# 0       Dog
# 1       Cat
# 2     Tiger
# 3      Lion
# 4    Monkey
# dtype: object

# %% [markdown]
# 튜플은 리스트와 차이는 없다.

# %%
import pandas as pd

tup_data = ('이순신', '1991-03-15', '남')
sd4 = pd.Series(tup_data, index = ['이름', '생년월일', '성별'])

sd4
# Out:
# 이름             이순신
# 생년월일    1991-03-15
# 성별               남
# dtype: object

# %%
import pandas as pd

dict_data = {'동물':['Dog','Cat','Tiger','Lion','Monkey'],'나이':[7,9,2,3,1]}
df1 = pd.DataFrame(dict_data)

print(type(df1))

print(df1)
# Out:
# <class 'pandas.core.frame.DataFrame'>
#        동물  나이
# 0     Dog   7
# 1     Cat   9
# 2   Tiger   2
# 3    Lion   3
# 4  Monkey   1

# %%
import pandas as pd

df2 = pd.DataFrame([['Dog','7'], ['Cat','9'], ['Tiger', '2'], ['Lion','3'],['Monkey','1']], index = ['0','1','2','3','4'], columns=['동물','나이'])

print(type(df2))
print(df2)
# Out:
# <class 'pandas.core.frame.DataFrame'>
#        동물 나이
# 0     Dog  7
# 1     Cat  9
# 2   Tiger  2
# 3    Lion  3
# 4  Monkey  1

# %%
import pandas as pd
import matplotlib as mpl
import matplotlib.pylab as plt
import seaborn as sns
import numpy as np

tips = sns.load_dataset("tips")
tips
tips.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   total_bill  244 non-null    float64
#  1   tip         244 non-null    float64
#  2   sex         244 non-null    category
#  3   smoker      244 non-null    category
#  4   day         244 non-null    category
#  5   time        244 non-null    category
#  6   size        244 non-null    int64
# dtypes: category(4), float64(2), int64(1)
# memory usage: 7.3 KB

# %%
tips.describe()
# Out:
#        total_bill         tip        size
# count  244.000000  244.000000  244.000000
# mean    19.785943    2.998279    2.569672
# std      8.902412    1.383638    0.951100
# min      3.070000    1.000000    1.000000
# 25%     13.347500    2.000000    2.000000
# 50%     17.795000    2.900000    2.000000
# 75%     24.127500    3.562500    3.000000
# max     50.810000   10.000000    6.000000

# %%
f = tips.groupby(['sex'])
print(f.get_group('Male').describe())
print(f.get_group('Female').describe())
# Out:
#        total_bill         tip        size
# count  157.000000  157.000000  157.000000
# mean    20.744076    3.089618    2.630573
# std      9.246469    1.489102    0.955997
# min      7.250000    1.000000    1.000000
# 25%     14.000000    2.000000    2.000000
# 50%     18.350000    3.000000    2.000000
# 75%     24.710000    3.760000    3.000000
# max     50.810000   10.000000    6.000000
#        total_bill        tip       size
# count   87.000000  87.000000  87.000000
# mean    18.056897   2.833448   2.459770
# std      8.009209   1.159495   0.937644
# min      3.070000   1.000000   1.000000
# 25%     12.750000   2.000000   2.000000
# 50%     16.400000   2.750000   2.000000
# 75%     21.520000   3.500000   3.000000
# max     44.300000   6.500000   6.000000

# %%
x = f.agg(['count', 'mean', 'std', 'min', 'max'])
x
# Out:
#        total_bill                                     tip                      \
#             count       mean       std   min    max count      mean       std
# sex
# Male          157  20.744076  9.246469  7.25  50.81   157  3.089618  1.489102
# Female         87  18.056897  8.009209  3.07  44.30    87  2.833448  1.159495
#
#                    size
#         min   max count      mean       std min max
# sex
# Male    1.0  10.0   157  2.630573  0.955997   1   6
# Female  1.0   6.5    87  2.459770  0.937644   1   6

# %%
tips['tip_percent'] = tips['tip'] / tips['total_bill']
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size  tip_percent
# 0         16.99  1.01  Female     No   Sun  Dinner     2     0.059447
# 1         10.34  1.66    Male     No   Sun  Dinner     3     0.160542
# 2         21.01  3.50    Male     No   Sun  Dinner     3     0.166587
# 3         23.68  3.31    Male     No   Sun  Dinner     2     0.139780
# 4         24.59  3.61  Female     No   Sun  Dinner     4     0.146808
# ..          ...   ...     ...    ...   ...     ...   ...          ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3     0.203927
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2     0.073584
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2     0.088222
# 242       17.82  1.75    Male     No   Sat  Dinner     2     0.098204
# 243       18.78  3.00  Female     No  Thur  Dinner     2     0.159744
#
# [244 rows x 8 columns]

# %%
plt.hist(tips['size'])
# Out:
# (array([  4.,   0., 156.,   0.,  38.,   0.,  37.,   0.,   5.,   4.]),
#  array([1. , 1.5, 2. , 2.5, 3. , 3.5, 4. , 4.5, 5. , 5.5, 6. ]),
#  <a list of 10 Patch objects>)

# %%
tips.sort_values(by=['tip_percent'], axis=0)
# Out:
#      total_bill   tip     sex smoker  day    time  size  tip_percent
# 237       32.83  1.17    Male    Yes  Sat  Dinner     2     0.035638
# 102       44.30  2.50  Female    Yes  Sat  Dinner     3     0.056433
# 57        26.41  1.50  Female     No  Sat  Dinner     2     0.056797
# 0         16.99  1.01  Female     No  Sun  Dinner     2     0.059447
# 187       30.46  2.00    Male    Yes  Sun  Dinner     5     0.065660
# ..          ...   ...     ...    ...  ...     ...   ...          ...
# 183       23.17  6.50    Male    Yes  Sun  Dinner     4     0.280535
# 232       11.61  3.39    Male     No  Sat  Dinner     2     0.291990
# 67         3.07  1.00  Female    Yes  Sat  Dinner     1     0.325733
# 178        9.60  4.00  Female    Yes  Sun  Dinner     2     0.416667
# 172        7.25  5.15    Male    Yes  Sun  Dinner     2     0.710345
#
# [244 rows x 8 columns]

# %%
sns.pairplot(tips, hue="sex")

# %%
sns.pairplot(tips, hue="sex", diag_kind="hist")

# %%
plt.boxplot(tips['tip_percent'])
plt.show()

# %%
plt.boxplot(tips['tip'])
plt.show()

# %%
tips.loc[0]
# Out:
# total_bill         16.99
# tip                 1.01
# sex               Female
# smoker                No
# day                  Sun
# time              Dinner
# size                   2
# tip_percent    0.0594467
# Name: 0, dtype: object

# %%
tips.loc[[1,3,5]]
# Out:
#    total_bill   tip   sex smoker  day    time  size  tip_percent
# 1       10.34  1.66  Male     No  Sun  Dinner     3     0.160542
# 3       23.68  3.31  Male     No  Sun  Dinner     2     0.139780
# 5       25.29  4.71  Male     No  Sun  Dinner     4     0.186240

# %%
tips.iloc[0]
# Out:
# total_bill         16.99
# tip                 1.01
# sex               Female
# smoker                No
# day                  Sun
# time              Dinner
# size                   2
# tip_percent    0.0594467
# Name: 0, dtype: object

# %%
tips.iloc[-1]
# Out:
# total_bill        18.78
# tip                   3
# sex              Female
# smoker               No
# day                Thur
# time             Dinner
# size                  2
# tip_percent    0.159744
# Name: 243, dtype: object

# %%
tips[0:3]
# Out:
#    total_bill   tip     sex smoker  day    time  size  tip_percent
# 0       16.99  1.01  Female     No  Sun  Dinner     2     0.059447
# 1       10.34  1.66    Male     No  Sun  Dinner     3     0.160542
# 2       21.01  3.50    Male     No  Sun  Dinner     3     0.166587

# %%
tips.loc[0:3]
# Out:
#    total_bill   tip     sex smoker  day    time  size  tip_percent
# 0       16.99  1.01  Female     No  Sun  Dinner     2     0.059447
# 1       10.34  1.66    Male     No  Sun  Dinner     3     0.160542
# 2       21.01  3.50    Male     No  Sun  Dinner     3     0.166587
# 3       23.68  3.31    Male     No  Sun  Dinner     2     0.139780

# %%
tips.loc[0:3,['sex','day']]
# Out:
#       sex  day
# 0  Female  Sun
# 1    Male  Sun
# 2    Male  Sun
# 3    Male  Sun

# %%
tips.loc[0,['sex','day']]
# Out:
# sex    Female
# day       Sun
# Name: 0, dtype: object

# %%
tips.at[0,'sex']
# Out:
# 'Female'

# %%
tips.iloc[3]
# Out:
# total_bill       23.68
# tip               3.31
# sex               Male
# smoker              No
# day                Sun
# time            Dinner
# size                 2
# tip_percent    0.13978
# Name: 3, dtype: object

# %%
tips.iloc[3:5,0:2]
# Out:
#    total_bill   tip
# 3       23.68  3.31
# 4       24.59  3.61

# %%
tips.iloc[[1,2,4],[0,2]]
# Out:
#    total_bill     sex
# 1       10.34    Male
# 2       21.01    Male
# 4       24.59  Female

# %%
tips.iloc[1:3,:]
# Out:
#    total_bill   tip   sex smoker  day    time  size  tip_percent
# 1       10.34  1.66  Male     No  Sun  Dinner     3     0.160542
# 2       21.01  3.50  Male     No  Sun  Dinner     3     0.166587

# %%
tips.iloc[:,1:3]
# Out:
#       tip     sex
# 0    1.01  Female
# 1    1.66    Male
# 2    3.50    Male
# 3    3.31    Male
# 4    3.61  Female
# ..    ...     ...
# 239  5.92    Male
# 240  2.00  Female
# 241  2.00    Male
# 242  1.75    Male
# 243  3.00  Female
#
# [244 rows x 2 columns]

# %%
tips.iloc[1,1]
# Out:
# 1.66

# %%
tips.iat[1,1]
# Out:
# 1.66

# %%
tips[tips.tip > 5]
# Out:
#      total_bill    tip     sex smoker   day    time  size  tip_percent
# 23        39.42   7.58    Male     No   Sat  Dinner     4     0.192288
# 44        30.40   5.60    Male     No   Sun  Dinner     4     0.184211
# 47        32.40   6.00    Male     No   Sun  Dinner     4     0.185185
# 52        34.81   5.20  Female     No   Sun  Dinner     4     0.149382
# 59        48.27   6.73    Male     No   Sat  Dinner     4     0.139424
# 85        34.83   5.17  Female     No  Thur   Lunch     4     0.148435
# 88        24.71   5.85    Male     No  Thur   Lunch     2     0.236746
# 116       29.93   5.07    Male     No   Sun  Dinner     4     0.169395
# 141       34.30   6.70    Male     No  Thur   Lunch     6     0.195335
# 155       29.85   5.14  Female     No   Sun  Dinner     5     0.172194
# 170       50.81  10.00    Male    Yes   Sat  Dinner     3     0.196812
# 172        7.25   5.15    Male    Yes   Sun  Dinner     2     0.710345
# 181       23.33   5.65    Male    Yes   Sun  Dinner     2     0.242177
# 183       23.17   6.50    Male    Yes   Sun  Dinner     4     0.280535
# 211       25.89   5.16    Male    Yes   Sat  Dinner     4     0.199305
# 212       48.33   9.00    Male     No   Sat  Dinner     4     0.186220
# 214       28.17   6.50  Female    Yes   Sat  Dinner     3     0.230742
# 239       29.03   5.92    Male     No   Sat  Dinner     3     0.203927

# %%
tips[(tips['sex']=='Male')&(tips['smoker']=='No')]
# Out:
#      total_bill   tip   sex smoker  day    time  size  tip_percent
# 1         10.34  1.66  Male     No  Sun  Dinner     3     0.160542
# 2         21.01  3.50  Male     No  Sun  Dinner     3     0.166587
# 3         23.68  3.31  Male     No  Sun  Dinner     2     0.139780
# 5         25.29  4.71  Male     No  Sun  Dinner     4     0.186240
# 6          8.77  2.00  Male     No  Sun  Dinner     2     0.228050
# ..          ...   ...   ...    ...  ...     ...   ...          ...
# 232       11.61  3.39  Male     No  Sat  Dinner     2     0.291990
# 233       10.77  1.47  Male     No  Sat  Dinner     2     0.136490
# 235       10.07  1.25  Male     No  Sat  Dinner     2     0.124131
# 239       29.03  5.92  Male     No  Sat  Dinner     3     0.203927
# 242       17.82  1.75  Male     No  Sat  Dinner     2     0.098204
#
# [97 rows x 8 columns]

# %%
[tips['day'].isin(['Sun'])]
# Out:
# [0       True
#  1       True
#  2       True
#  3       True
#  4       True
#         ...
#  239    False
#  240    False
#  241    False
#  242    False
#  243    False
#  Name: day, Length: 244, dtype: bool]

# %%
tips[tips['tip'].isin([1])]
# Out:
#      total_bill  tip     sex smoker  day    time  size  tip_percent
# 67         3.07  1.0  Female    Yes  Sat  Dinner     1     0.325733
# 92         5.75  1.0  Female    Yes  Fri  Dinner     2     0.173913
# 111        7.25  1.0  Female     No  Sat  Dinner     1     0.137931
# 236       12.60  1.0    Male    Yes  Sat  Dinner     2     0.079365

# %%
tips.tip
# Out:
# 0      1.01
# 1      1.66
# 2      3.50
# 3      3.31
# 4      3.61
#        ...
# 239    5.92
# 240    2.00
# 241    2.00
# 242    1.75
# 243    3.00
# Name: tip, Length: 244, dtype: float64

# %%
tips['size']
# Out:
# 0      2
# 1      3
# 2      3
# 3      2
# 4      4
#       ..
# 239    3
# 240    2
# 241    2
# 242    2
# 243    2
# Name: size, Length: 244, dtype: int64

# %%
tips.dtypes
# Out:
# total_bill      float64
# tip             float64
# sex            category
# smoker         category
# day            category
# time           category
# size              int64
# tip_percent     float64
# dtype: object

# %%
type(tips.total_bill)
# Out:
# pandas.core.series.Series

# %%
tips['smoker_str']=tips['smoker'].astype(str)

# %%
tips.dtypes
# Out:
# total_bill      float64
# tip             float64
# sex            category
# smoker         category
# day            category
# time           category
# size              int64
# tip_percent     float64
# smoker_str       object
# dtype: object

# %%
tips.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 9 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   total_bill   244 non-null    float64
#  1   tip          244 non-null    float64
#  2   sex          244 non-null    category
#  3   smoker       244 non-null    category
#  4   day          244 non-null    category
#  5   time         244 non-null    category
#  6   size         244 non-null    int64
#  7   tip_percent  244 non-null    float64
#  8   smoker_str   244 non-null    object
# dtypes: category(4), float64(3), int64(1), object(1)
# memory usage: 11.1+ KB

# %%
tips['smoker_str'] = tips['smoker'].astype('category')

tips.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 9 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   total_bill   244 non-null    float64
#  1   tip          244 non-null    float64
#  2   sex          244 non-null    category
#  3   smoker       244 non-null    category
#  4   day          244 non-null    category
#  5   time         244 non-null    category
#  6   size         244 non-null    int64
#  7   tip_percent  244 non-null    float64
#  8   smoker_str   244 non-null    category
# dtypes: category(5), float64(3), int64(1)
# memory usage: 9.5 KB

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size  tip_percent smoker_str
# 0       16.99  1.01  Female     No  Sun  Dinner     2     0.059447         No
# 1       10.34  1.66    Male     No  Sun  Dinner     3     0.160542         No
# 2       21.01  3.50    Male     No  Sun  Dinner     3     0.166587         No
# 3       23.68  3.31    Male     No  Sun  Dinner     2     0.139780         No
# 4       24.59  3.61  Female     No  Sun  Dinner     4     0.146808         No

# %%
tips.head(2)
# Out:
#    total_bill   tip     sex smoker  day    time  size  tip_percent smoker_str
# 0       16.99  1.01  Female     No  Sun  Dinner     2     0.059447         No
# 1       10.34  1.66    Male     No  Sun  Dinner     3     0.160542         No

# %%
print(tips.head())
print(tips.head(2))
print(tips.tail())
print(tips.tail(3))
# Out:
#    total_bill   tip     sex smoker  day    time  size  tip_percent smoker_str
# 0       16.99  1.01  Female     No  Sun  Dinner     2     0.059447         No
# 1       10.34  1.66    Male     No  Sun  Dinner     3     0.160542         No
# 2       21.01  3.50    Male     No  Sun  Dinner     3     0.166587         No
# 3       23.68  3.31    Male     No  Sun  Dinner     2     0.139780         No
# 4       24.59  3.61  Female     No  Sun  Dinner     4     0.146808         No
#    total_bill   tip     sex smoker  day    time  size  tip_percent smoker_str
# 0       16.99  1.01  Female     No  Sun  Dinner     2     0.059447         No
# 1       10.34  1.66    Male     No  Sun  Dinner     3     0.160542         No
#      total_bill   tip     sex smoker   day    time  size  tip_percent  \
# 239       29.03  5.92    Male     No   Sat  Dinner     3     0.203927
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2     0.073584
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2     0.088222
# 242       17.82  1.75    Male     No   Sat  Dinner     2     0.098204
# 243       18.78  3.00  Female     No  Thur  Dinner     2     0.159744
#
#     smoker_str
# 239         No
# 240        Yes
# 241        Yes
# 242         No
# 243         No
#      total_bill   tip     sex smoker   day    time  size  tip_percent  \
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2     0.088222
# 242       17.82  1.75    Male     No   Sat  Dinner     2     0.098204
# 243       18.78  3.00  Female     No  Thur  Dinner     2     0.159744
#
#     smoker_str
# 241        Yes
# 242         No
# 243         No

# %%
tips[['total_bill','tip','day']]
# Out:
#      total_bill   tip   day
# 0         16.99  1.01   Sun
# 1         10.34  1.66   Sun
# 2         21.01  3.50   Sun
# 3         23.68  3.31   Sun
# 4         24.59  3.61   Sun
# ..          ...   ...   ...
# 239       29.03  5.92   Sat
# 240       27.18  2.00   Sat
# 241       22.67  2.00   Sat
# 242       17.82  1.75   Sat
# 243       18.78  3.00  Thur
#
# [244 rows x 3 columns]

# %%
tips['total']=tips['total_bill'] + tips['tip']
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size  tip_percent  \
# 0         16.99  1.01  Female     No   Sun  Dinner     2     0.059447
# 1         10.34  1.66    Male     No   Sun  Dinner     3     0.160542
# 2         21.01  3.50    Male     No   Sun  Dinner     3     0.166587
# 3         23.68  3.31    Male     No   Sun  Dinner     2     0.139780
# 4         24.59  3.61  Female     No   Sun  Dinner     4     0.146808
# ..          ...   ...     ...    ...   ...     ...   ...          ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3     0.203927
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2     0.073584
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2     0.088222
# 242       17.82  1.75    Male     No   Sat  Dinner     2     0.098204
# 243       18.78  3.00  Female     No  Thur  Dinner     2     0.159744
#
#     smoker_str  total
# 0           No  18.00
# 1           No  12.00
# 2           No  24.51
# 3           No  26.99
# 4           No  28.20
# ..         ...    ...
# 239         No  34.95
# 240        Yes  29.18
# 241        Yes  24.67
# 242         No  19.57
# 243         No  21.78
#
# [244 rows x 10 columns]

# %%
tips.count()
len(tips)
# Out:
# 244

# %%
print(tips.index)
print(tips.columns)
print(tips.values)
# Out:
# RangeIndex(start=0, stop=244, step=1)
# Index(['total_bill', 'tip', 'sex', 'smoker', 'day', 'time', 'size',
#        'tip_percent', 'smoker_str', 'total'],
#       dtype='object')
# [[16.99 1.01 'Female' ... 0.05944673337257211 'No' 18.0]
#  [10.34 1.66 'Male' ... 0.16054158607350097 'No' 12.0]
#  [21.01 3.5 'Male' ... 0.16658733936220846 'No' 24.51]
#  ...
#  [22.67 2.0 'Male' ... 0.08822232024702249 'Yes' 24.67]
#  [17.82 1.75 'Male' ... 0.09820426487093153 'No' 19.57]
#  [18.78 3.0 'Female' ... 0.1597444089456869 'No' 21.78]]

# %%
tips.sort_values(by=['total_bill'],axis=0)
# Out:
#      total_bill    tip     sex smoker   day    time  size  tip_percent  \
# 67         3.07   1.00  Female    Yes   Sat  Dinner     1     0.325733
# 92         5.75   1.00  Female    Yes   Fri  Dinner     2     0.173913
# 111        7.25   1.00  Female     No   Sat  Dinner     1     0.137931
# 172        7.25   5.15    Male    Yes   Sun  Dinner     2     0.710345
# 149        7.51   2.00    Male     No  Thur   Lunch     2     0.266312
# ..          ...    ...     ...    ...   ...     ...   ...          ...
# 182       45.35   3.50    Male    Yes   Sun  Dinner     3     0.077178
# 156       48.17   5.00    Male     No   Sun  Dinner     6     0.103799
# 59        48.27   6.73    Male     No   Sat  Dinner     4     0.139424
# 212       48.33   9.00    Male     No   Sat  Dinner     4     0.186220
# 170       50.81  10.00    Male    Yes   Sat  Dinner     3     0.196812
#
#     smoker_str  total
# 67         Yes   4.07
# 92         Yes   6.75
# 111         No   8.25
# 172        Yes  12.40
# 149         No   9.51
# ..         ...    ...
# 182        Yes  48.85
# 156         No  53.17
# 59          No  55.00
# 212         No  57.33
# 170        Yes  60.81
#
# [244 rows x 10 columns]

# %%
tips.sort_values(by=['total_bill'], axis=0, ascending=False)
# Out:
#      total_bill    tip     sex smoker   day    time  size  tip_percent  \
# 170       50.81  10.00    Male    Yes   Sat  Dinner     3     0.196812
# 212       48.33   9.00    Male     No   Sat  Dinner     4     0.186220
# 59        48.27   6.73    Male     No   Sat  Dinner     4     0.139424
# 156       48.17   5.00    Male     No   Sun  Dinner     6     0.103799
# 182       45.35   3.50    Male    Yes   Sun  Dinner     3     0.077178
# ..          ...    ...     ...    ...   ...     ...   ...          ...
# 149        7.51   2.00    Male     No  Thur   Lunch     2     0.266312
# 111        7.25   1.00  Female     No   Sat  Dinner     1     0.137931
# 172        7.25   5.15    Male    Yes   Sun  Dinner     2     0.710345
# 92         5.75   1.00  Female    Yes   Fri  Dinner     2     0.173913
# 67         3.07   1.00  Female    Yes   Sat  Dinner     1     0.325733
#
#     smoker_str  total
# 170        Yes  60.81
# 212         No  57.33
# 59          No  55.00
# 156         No  53.17
# 182        Yes  48.85
# ..         ...    ...
# 149         No   9.51
# 111         No   8.25
# 172        Yes  12.40
# 92         Yes   6.75
# 67         Yes   4.07
#
# [244 rows x 10 columns]

# %%
tips.sort_index(axis=1)
# Out:
#       day     sex  size smoker smoker_str    time   tip  tip_percent  total  \
# 0     Sun  Female     2     No         No  Dinner  1.01     0.059447  18.00
# 1     Sun    Male     3     No         No  Dinner  1.66     0.160542  12.00
# 2     Sun    Male     3     No         No  Dinner  3.50     0.166587  24.51
# 3     Sun    Male     2     No         No  Dinner  3.31     0.139780  26.99
# 4     Sun  Female     4     No         No  Dinner  3.61     0.146808  28.20
# ..    ...     ...   ...    ...        ...     ...   ...          ...    ...
# 239   Sat    Male     3     No         No  Dinner  5.92     0.203927  34.95
# 240   Sat  Female     2    Yes        Yes  Dinner  2.00     0.073584  29.18
# 241   Sat    Male     2    Yes        Yes  Dinner  2.00     0.088222  24.67
# 242   Sat    Male     2     No         No  Dinner  1.75     0.098204  19.57
# 243  Thur  Female     2     No         No  Dinner  3.00     0.159744  21.78
#
#      total_bill
# 0         16.99
# 1         10.34
# 2         21.01
# 3         23.68
# 4         24.59
# ..          ...
# 239       29.03
# 240       27.18
# 241       22.67
# 242       17.82
# 243       18.78
#
# [244 rows x 10 columns]

# %%
tips.sum(axis=1)
# Out:
# 0      38.059447
# 1      27.160542
# 2      52.186587
# 3      56.119780
# 4      60.546808
#          ...
# 239    73.103927
# 240    60.433584
# 241    51.428222
# 242    41.238204
# 243    45.719744
# Length: 244, dtype: float64

# %%
tips.sum()
# Out:
# total_bill                                               4827.77
# tip                                                       731.58
# sex            FemaleMaleMaleMaleFemaleMaleMaleMaleMaleMaleMa...
# smoker         NoNoNoNoNoNoNoNoNoNoNoNoNoNoNoNoNoNoNoNoNoNoNo...
# day            SunSunSunSunSunSunSunSunSunSunSunSunSunSunSunS...
# time           DinnerDinnerDinnerDinnerDinnerDinnerDinnerDinn...
# size                                                         627
# tip_percent                                              39.2358
# smoker_str     NoNoNoNoNoNoNoNoNoNoNoNoNoNoNoNoNoNoNoNoNoNoNo...
# total                                                    5559.35
# dtype: object

# %%
import pandas as pd
import matplotlib as mpl
import matplotlib.pylab as plt
import seaborn as sns
import numpy as np

tips = sns.load_dataset("tips")
print(tips)
print(tips.dtypes)
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]
# total_bill     float64
# tip            float64
# sex           category
# smoker        category
# day           category
# time          category
# size             int64
# dtype: object

# %%
tips['sex'].value_counts()
# Out:
# Male      157
# Female     87
# Name: sex, dtype: int64

# %%
tips['day'].value_counts()
# Out:
# Sat     87
# Sun     76
# Thur    62
# Fri     19
# Name: day, dtype: int64

# %%
pd.crosstab(tips['sex'],tips['day'])
# Out:
# day     Thur  Fri  Sat  Sun
# sex
# Male      30   10   59   58
# Female    32    9   28   18

# %%
pd.crosstab(tips['sex'],tips['day'])
# Out:
# day     Thur  Fri  Sat  Sun
# sex
# Male      30   10   59   58
# Female    32    9   28   18

# %%
pd.crosstab(tips['sex'], tips['day'], margins=True)
# Out:
# day     Thur  Fri  Sat  Sun  All
# sex
# Male      30   10   59   58  157
# Female    32    9   28   18   87
# All       62   19   87   76  244

# %%
pd.pivot

# %%
pd.crosstab(tips['sex'],tips['day']).apply(lambda r:r/len(tips), axis=1)
# Out:
# day         Thur       Fri       Sat       Sun
# sex
# Male    0.122951  0.040984  0.241803  0.237705
# Female  0.131148  0.036885  0.114754  0.073770

# %%
tips.dtypes
# Out:
# total_bill     float64
# tip            float64
# sex           category
# smoker        category
# day           category
# time          category
# size             int64
# dtype: object

# %%
tips.describe()
# Out:
#        total_bill         tip        size
# count  244.000000  244.000000  244.000000
# mean    19.785943    2.998279    2.569672
# std      8.902412    1.383638    0.951100
# min      3.070000    1.000000    1.000000
# 25%     13.347500    2.000000    2.000000
# 50%     17.795000    2.900000    2.000000
# 75%     24.127500    3.562500    3.000000
# max     50.810000   10.000000    6.000000

# %%
tips.plot()

# %%
tips.plot(kind='line')

# %%
tips.plot(kind='hist')

# %%
tips.plot(kind='box')

# %%
s1=pd.Series([0,1], index=['A','B'])
s2=pd.Series([2,3,4], index=['c','d','e'])
s1
# Out:
# A    0
# B    1
# dtype: int64

# %%
s2
# Out:
# c    2
# d    3
# e    4
# dtype: int64

# %%
pd.concat([s1,s2])
# Out:
# A    0
# B    1
# c    2
# d    3
# e    4
# dtype: int64

# %%
df1 = pd.DataFrame([['Dog','3'],['Bird','10'],['Tiger','6'],['Moose','3']],index=['0','1','2','3'], columns=['동물','나이'])
df1
# Out:
#       동물  나이
# 0    Dog   3
# 1   Bird  10
# 2  Tiger   6
# 3  Moose   3

# %%
df2=pd.DataFrame([['집','0'],['초원','0'],['수풀','0'],['초원','1']],index=['0','1','2','3'],columns=['사는곳','뿔의 개수'])
df2
# Out:
#   사는곳 뿔의 개수
# 0   집     0
# 1  초원     0
# 2  수풀     0
# 3  초원     1

# %%
pd.concat([df1, df2], axis=1)
# Out:
#       동물  나이 사는곳 뿔의 개수
# 0    Dog   3   집     0
# 1   Bird  10  초원     0
# 2  Tiger   6  수풀     0
# 3  Moose   3  초원     1

# %%
import pandas as pd

df1=pd.DataFrame({'고객번호':[1001,1002,1003,1004,1005,1006,1007],'이름':['강감찬','홍길동','이순신','장보고','유관순','신사임당','세종대왕']}, columns=['고객번호','이름'])
df1
# Out:
#    고객번호    이름
# 0  1001   강감찬
# 1  1002   홍길동
# 2  1003   이순신
# 3  1004   장보고
# 4  1005   유관순
# 5  1006  신사임당
# 6  1007  세종대왕

# %%
df2 = pd.DataFrame({'고객번호':[1001,1001,1005,1006,1008,1001],'금액':['10000','20000','15000','5000','100000','30000']}, columns=['고객번호','금액'])
df2
# Out:
#    고객번호      금액
# 0  1001   10000
# 1  1001   20000
# 2  1005   15000
# 3  1006    5000
# 4  1008  100000
# 5  1001   30000

# %%
pd.merge(df1,df2)
# Out:
#    고객번호    이름     금액
# 0  1001   강감찬  10000
# 1  1001   강감찬  20000
# 2  1001   강감찬  30000
# 3  1005   유관순  15000
# 4  1006  신사임당   5000

# %%
pd.merge(df1,df2,how='outer')
# Out:
#    고객번호    이름      금액
# 0  1001   강감찬   10000
# 1  1001   강감찬   20000
# 2  1001   강감찬   30000
# 3  1002   홍길동     NaN
# 4  1003   이순신     NaN
# 5  1004   장보고     NaN
# 6  1005   유관순   15000
# 7  1006  신사임당    5000
# 8  1007  세종대왕     NaN
# 9  1008   NaN  100000

# %%
pd.merge(df1,df2,how='left')
# Out:
#    고객번호    이름     금액
# 0  1001   강감찬  10000
# 1  1001   강감찬  20000
# 2  1001   강감찬  30000
# 3  1002   홍길동    NaN
# 4  1003   이순신    NaN
# 5  1004   장보고    NaN
# 6  1005   유관순  15000
# 7  1006  신사임당   5000
# 8  1007  세종대왕    NaN

# %%
pd.merge(df1, df2, how='right')
# Out:
#    고객번호    이름      금액
# 0  1001   강감찬   10000
# 1  1001   강감찬   20000
# 2  1001   강감찬   30000
# 3  1005   유관순   15000
# 4  1006  신사임당    5000
# 5  1008   NaN  100000
